# %%
import xgboost

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/72.0 MB 3.7 MB/s eta 0:00:20
#     --------------------------------------- 1.0/72.0 MB 3.1 MB/s eta 0:00:23
#    - -------------------------------------- 1.8/72.0 MB 3.0 MB/s eta 0:00:24
#    - -------------------------------------- 2.4/72.0 MB 3.1 MB/s eta 0:00:23
#    - -------------------------------------- 2.9/72.0 MB 3.1 MB/s eta 0:00:23
#    -- ------------------------------------- 3.7/72.0 MB 2.9 MB/s eta 0:00:24
#    -- ------------------------------------- 4.5/72.0 MB 3.0 MB/s eta 0:00:23
#    -- ------------------------------------- 5.2/72.0 MB 3.1 MB/s eta 0:00:22
#    --- ------------------------------------ 6.0/72.0 MB 3.2 MB/s eta 0:00:21
#    --- ------------------------------------ 6.8/72.0 MB 3.3 MB/s eta 0:00:20
#    ---- ----------------------------------- 7.9/72.0 MB 3.4 MB/s eta 0:00:19
# ...
