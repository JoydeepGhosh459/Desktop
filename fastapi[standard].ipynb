# %%
pip install "fastapi[standard]"
# Out:
# ...
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/726.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/726.2 kB ? eta -:--:--
# ...
